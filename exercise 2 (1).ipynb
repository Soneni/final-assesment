# %% [markdown]
# # Data science tools and ecosystem

# %% [markdown]
# introduction to my graded peer review assignment. please grade fairly

# %% [markdown]
# data science languages
# 1. python
# 1. SQL
# 1. JAVA
# 1. SCALA
# 1. JAVASCRIPT
# 1. JULIA

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pytorch
# 1. Tensorflow
# 1. scikit-learn
# 1. OpenCV

# %% [markdown]
# | Data science tools|
# |-------------------|
# |Apache spark|
# |Python|
# |Tensorflow|
# |Matlab|
# |pytorch|
# |Rstudio|
# |Julia|
# |Numpy|

# %% [markdown]
# next cells will multiply and add numbers in simple arithmetic processes

# %%
x= int(input("enter a number: "))
y= int(input("enter another number: "))
z= int(input("enter another number: "))
print ("the Multiplication of x and y numbers added to z=", (x*y)+ z,)
# Out:
# enter a number: 50
# enter another number: 60
# enter another number: 40
# the Multiplication of x and y numbers added to z= 3040

# %%
hours=int(input("enter number of hours:")) 
minutes=hours*60
print(f"{hours} hours is {minutes} minutes")
# Out:
# enter number of hours:5
# 5 hours is 300 minutes

# %% [markdown]
# **Objectives**
# * create a couple markdown lists
# * publish notebook to github
# * finish week 4

# %% [markdown]
# ## Athour
# **SONENI HANDA**
